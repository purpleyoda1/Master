# %% [markdown]
# Check for GPU

# %%
# !nvidia-smi
# Out:
# Wed Nov  6 17:47:02 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   38C    P5             N/A /  115W |    2092MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# Set up directory

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\sondr\Documents\NTNU\9_semester\prosjekt\scripts

# %% [markdown]
# Load ultralytics

# %%
import ultralytics
import torchvision

ultralytics.checks()
torchvision.__version__
# Out:
# Ultralytics 8.3.15  Python-3.8.20 torch-2.3.0 CPU (AMD Ryzen 5 7500F 6-Core Processor)
# Setup complete  (12 CPUs, 15.7 GB RAM, 289.0/930.8 GB disk)
# '0.18.1a0'

# %% [markdown]
# HOME: Train it on custom dataset

# %%
# !yolo task=detect mode=train model=yolov10s.pt data=data.yaml epochs=20 imgsz=424 plots=True
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.8.20 is currently installed
#   0%|          | 0.00/15.9M [00:00<?, ?B/s]
#   6%|▋         | 1.00M/15.9M [00:00<00:01, 9.74MB/s]
#  15%|█▍        | 2.38M/15.9M [00:00<00:01, 11.7MB/s]
#  24%|██▎       | 3.75M/15.9M [00:00<00:01, 12.5MB/s]
#  32%|███▏      | 5.00M/15.9M [00:00<00:01, 10.6MB/s]
#  39%|███▉      | 6.25M/15.9M [00:00<00:00, 11.3MB/s]
#  48%|████▊     | 7.62M/15.9M [00:00<00:00, 11.9MB/s]
#  56%|█████▌    | 8.88M/15.9M [00:00<00:00, 10.9MB/s]
#  64%|██████▍   | 10.1M/15.9M [00:00<00:00, 11.2MB/s]
#  73%|███████▎  | 11.5M/15.9M [00:01<00:00, 11.8MB/s]
#  80%|████████  | 12.8M/15.9M [00:01<00:00, 12.2MB/s]
#  88%|████████▊ | 14.0M/15.9M [00:01<00:00, 12.4MB/s]
#  97%|█████████▋| 15.4M/15.9M [00:01<00:00, 12.6MB/s]
# 100%|██████████| 15.9M/15.9M [00:01<00:00, 11.9MB/s]
#
# train: Scanning C:\Users\sondr\Documents\NTNU\9_semester\prosjekt\synthetic_data\training\labels\train...:   0%|          | 0/949 [00:00<?, ?it/s]
# ...

# %% [markdown]
# HOME: Apply to test set

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train_s/weights/best.pt conf=0.25 source={HOME}/../3_test_1min_hamkam_from_start/img1 save=True
